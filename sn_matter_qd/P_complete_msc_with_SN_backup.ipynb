# %%
from Pij_sn import Pij_SN_surface_E

def Pee_combined_E(n, D_kpc, E, Gamma3, Gamma8, mix, regeneration, thetaz, nu_nubar, oscil_par, detector, sn_matter):
    theta12, Deltam21 = oscil_par
    c12=np.cos(theta12)
    s12=np.sin(theta12)
    c13=np.cos(theta13)
    s13=np.sin(theta13)
    c23=np.cos(theta23)
    s23=np.sin(theta23)

    U23 = np.array([ [1,0,0],[0,c23,s23],[0,-s23,c23] ])
    U13 = np.array([ [c13,0,s13],[0,1,0],[-s13,0,c13] ])
    U12 = np.array([ [c12,s12,0],[-s12,c12,0],[0,0,1] ])
    U3 = U23 @ U13 @ U12

    if sn_matter == 'yes':
        D_kpc = D_kpc - 1.92594212046e-8 #removing SN radius

    P11 = P11_E_func(n, E, D_kpc, Gamma3, Gamma8)
    P12 = P12_E_func(n, E, D_kpc, Gamma3, Gamma8)
    P31 = P31_E_func(n, E, D_kpc, Gamma8)
    P33 = P33_E_func(n, E, D_kpc, Gamma8)

    # print(P11,P12,P31,P33)
    P21 = P12
    P22 = P11
    P23 = P31
    P13 = P31
    P32 = P31

    #OQS impact on Earth matter effects:
    #since I tested, there is no much impact on the probability of matter + relaxation effect, the values keep always as is
    Pearth11 = 1
    Pearth12 = 0
    Pearth13 = 0
    Pearth21 = 0
    Pearth22 = 1
    Pearth23 = 0
    Pearth31 = 0
    Pearth32 = 0
    Pearth33 = 1

    if regeneration == 'no':
        P1e_earth = abs(U3[0,0])**2
        P2e_earth = abs(U3[0,1])**2
        P3e_earth = abs(U3[0,2])**2
    
    if nu_nubar == 'nue':
        if mix  == 'NH':
            if regeneration == 'yes':
                P1e_earth = abs(U3[0,0])**2
                P2e_earth = abs(U3[0,1])**2
                P3e_earth = abs(U3[0,2])**2

            #Pe3sn = 1 is hidden
            #old:
            # Psn31 = Pij_sn.Pij_SN_surface(Gamma3, Gamma8, mix, '31', nu_nubar)
            # Psn32 = Pij_sn.Pij_SN_surface(Gamma3, Gamma8, mix, '32', nu_nubar)
            # Psn33 = Pij_sn.Pij_SN_surface(Gamma3, Gamma8, mix, '33', nu_nubar)

            #To include SN matter effects, uncomment:
            if sn_matter == 'yes':
                Psn31 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '31', nu_nubar)
                Psn32 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '32', nu_nubar)
                Psn33 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '33', nu_nubar)

            else:
                Psn31 = 0
                Psn32 = 0
                Psn33 = 1
            
            Pee = Psn31*P11*Pearth11*P1e_earth + Psn31*P11*Pearth12*P2e_earth + Psn31*P11*Pearth13*P3e_earth + Psn31*P12*Pearth21*P1e_earth + Psn31*P12*Pearth22*P2e_earth + Psn31*P12*Pearth23*P3e_earth + Psn31*P13*Pearth31*P1e_earth + Psn31*P13*Pearth32*P2e_earth + Psn31*P13*Pearth33*P3e_earth + Psn32*P21*Pearth11*P1e_earth + Psn32*P21*Pearth12*P2e_earth + Psn32*P21*Pearth13*P3e_earth + Psn32*P22*Pearth21*P1e_earth + Psn32*P22*Pearth22*P2e_earth + Psn32*P22*Pearth23*P3e_earth + Psn32*P23*Pearth31*P1e_earth + Psn32*P23*Pearth32*P2e_earth + Psn32*P23*Pearth33*P3e_earth + Psn33*P31*Pearth11*P1e_earth + Psn33*P31*Pearth12*P2e_earth + Psn33*P31*Pearth13*P3e_earth + Psn33*P32*Pearth21*P1e_earth + Psn33*P32*Pearth22*P2e_earth + Psn33*P32*Pearth23*P3e_earth + Psn33*P33*Pearth31*P1e_earth + Psn33*P33*Pearth32*P2e_earth + Psn33*P33*Pearth33*P3e_earth
        
        elif mix  == 'IH':
            if regeneration == 'yes':
                if thetaz == 180:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_ih_nue_180_func, P2e_ih_nue_180_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_180_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_129_3_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2

                elif thetaz == 160:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_ih_nue_160_func, P2e_ih_nue_160_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_160_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_ih_nue_118_func, P2e_ih_nue_129_6_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_129_6_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 140:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_ih_nue_140_func, P2e_ih_nue_140_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_140_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2

                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_ih_nue_98_func, P2e_ih_nue_95_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_95_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 120:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_ih_nue_120_func, P2e_ih_nue_120_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_120_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_ih_nue_78_func, P2e_ih_nue_97_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_97_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2

                
                elif thetaz == 340:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_ih_nue_160_func, P2e_ih_nue_160_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,2])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_ih_nue_118_func, P2e_ih_nue_129_6_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_95_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_120_8_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 320:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_ih_nue_160_func, P2e_ih_nue_160_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,2])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_ih_nue_118_func, P2e_ih_nue_129_6_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_129_6_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_146_6_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 300:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_ih_nue_160_func, P2e_ih_nue_160_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,2])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_ih_nue_118_func, P2e_ih_nue_129_6_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_129_3_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_146_6_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 0:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_ih_nue_160_func, P2e_ih_nue_160_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,2])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_ih_nue_118_func, P2e_ih_nue_129_6_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = P2e_ih_nue_105_func(w21, theta12)
                        P3e_earth = abs(U3[0,2])**2
                    

            else:
                P1e_earth = abs(U3[0,0])**2
                P2e_earth = abs(U3[0,1])**2
                P3e_earth = abs(U3[0,2])**2

            #Pe2sn = 1 is hidden
            if sn_matter == 'yes':
                Psn21 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '21', nu_nubar)
                Psn22 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '22', nu_nubar)
                Psn23 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '23', nu_nubar)
            else:
                Psn21 = 0
                Psn22 = 1
                Psn23 = 0

            Pee = Psn21*P11*Pearth11*P1e_earth + Psn21*P11*Pearth12*P2e_earth + Psn21*P11*Pearth13*P3e_earth + Psn21*P12*Pearth21*P1e_earth + Psn21*P12*Pearth22*P2e_earth + Psn21*P12*Pearth23*P3e_earth + Psn21*P13*Pearth31*P1e_earth + Psn21*P13*Pearth32*P2e_earth + Psn21*P13*Pearth33*P3e_earth + Psn22*P21*Pearth11*P1e_earth + Psn22*P21*Pearth12*P2e_earth + Psn22*P21*Pearth13*P3e_earth + Psn22*P22*Pearth21*P1e_earth + Psn22*P22*Pearth22*P2e_earth + Psn22*P22*Pearth23*P3e_earth + Psn22*P23*Pearth31*P1e_earth + Psn22*P23*Pearth32*P2e_earth + Psn22*P23*Pearth33*P3e_earth + Psn23*P31*Pearth11*P1e_earth + Psn23*P31*Pearth12*P2e_earth + Psn23*P31*Pearth13*P3e_earth + Psn23*P32*Pearth21*P1e_earth + Psn23*P32*Pearth22*P2e_earth + Psn23*P32*Pearth23*P3e_earth + Psn23*P33*Pearth31*P1e_earth + Psn23*P33*Pearth32*P2e_earth + Psn23*P33*Pearth33*P3e_earth

    #conferir nuebar!
    elif nu_nubar == 'nuebar':
        if mix  == 'NH':
            if regeneration == 'yes':
                if thetaz == 180:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_nh_nuebar_180_func, P2e_nh_nuebar_180_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_180_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_nh_nuebar_138_func, P2e_nh_nuebar_138_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_129_3_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2

                elif thetaz == 160:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_nh_nuebar_160_func, P2e_nh_nuebar_160_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_160_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_nh_nuebar_118_func, P2e_nh_nuebar_118_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_129_6_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 140:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_nh_nuebar_140_func, P2e_nh_nuebar_140_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_140_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2

                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_nh_nuebar_95_func, P2e_nh_nuebar_98_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_95_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 120:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_nh_nuebar_120_func, P2e_nh_nuebar_120_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_120_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_nh_nuebar_97_func, P2e_nh_nuebar_78_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_97_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 0:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_nh_nuebar_120_func, P2e_nh_nuebar_120_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_nh_nuebar_97_func, P2e_nh_nuebar_78_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_105_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 340:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_nh_nuebar_120_func, P2e_nh_nuebar_120_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_nh_nuebar_97_func, P2e_nh_nuebar_78_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_95_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_120_8_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 320:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_nh_nuebar_120_func, P2e_nh_nuebar_120_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_nh_nuebar_97_func, P2e_nh_nuebar_78_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_129_6_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_146_6_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                
                elif thetaz == 300:
                    if detector == 'DUNE':
                        # from Pie_earth_interps import P1e_nh_nuebar_120_func, P2e_nh_nuebar_120_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = abs(U3[0,0])**2
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'HK':
                        # from Pie_earth_interps import P1e_nh_nuebar_97_func, P2e_nh_nuebar_78_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_129_3_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2
                    
                    elif detector == 'JN':
                        # from Pie_earth_interps import P1e_ih_nue_138_func, P2e_ih_nue_129_3_func
                        w21 = Deltam21/(E*1e6)
                        P1e_earth = P1e_nh_nuebar_146_6_func(w21, theta12)
                        P2e_earth = abs(U3[0,1])**2
                        P3e_earth = abs(U3[0,2])**2

            else:
                P1e_earth = abs(U3[0,0])**2
                P2e_earth = abs(U3[0,1])**2
                P3e_earth = abs(U3[0,2])**2

            #Pe1sn = 1 is hidden
            if sn_matter == 'yes':
                Psn11 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '11', nu_nubar)
                Psn12 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '12', nu_nubar)
                Psn13 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '13', nu_nubar)
            else:
                Psn11 = 1
                Psn12 = 0
                Psn13 = 0

            Pee = Psn11*P11*Pearth11*P1e_earth + Psn11*P11*Pearth12*P2e_earth + Psn11*P11*Pearth13*P3e_earth + Psn11*P12*Pearth21*P1e_earth + Psn11*P12*Pearth22*P2e_earth + Psn11*P12*Pearth23*P3e_earth + Psn11*P13*Pearth31*P1e_earth + Psn11*P13*Pearth32*P2e_earth + Psn11*P13*Pearth33*P3e_earth + Psn12*P21*Pearth11*P1e_earth + Psn12*P21*Pearth12*P2e_earth + Psn12*P21*Pearth13*P3e_earth + Psn12*P22*Pearth21*P1e_earth + Psn12*P22*Pearth22*P2e_earth + Psn12*P22*Pearth23*P3e_earth + Psn12*P23*Pearth31*P1e_earth + Psn12*P23*Pearth32*P2e_earth + Psn12*P23*Pearth33*P3e_earth + Psn13*P31*Pearth11*P1e_earth + Psn13*P31*Pearth12*P2e_earth + Psn13*P31*Pearth13*P3e_earth + Psn13*P32*Pearth21*P1e_earth + Psn13*P32*Pearth22*P2e_earth + Psn13*P32*Pearth23*P3e_earth + Psn13*P33*Pearth31*P1e_earth + Psn13*P33*Pearth32*P2e_earth + Psn13*P33*Pearth33*P3e_earth
        
        elif mix  == 'IH':
            P1e_earth = abs(U3[0,0])**2
            P2e_earth = abs(U3[0,1])**2
            P3e_earth = abs(U3[0,2])**2

            #Pe3sn = 1 is hidden
            if sn_matter == 'yes':
                Psn31 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '31', nu_nubar)
                Psn32 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '32', nu_nubar)
                Psn33 = Pij_SN_surface_E(n, E, Gamma3, Gamma8, mix, '33', nu_nubar)
            else:
                Psn31 = 0
                Psn32 = 0
                Psn33 = 1

            Pee = Psn31*P11*Pearth11*P1e_earth + Psn31*P11*Pearth12*P2e_earth + Psn31*P11*Pearth13*P3e_earth + Psn31*P12*Pearth21*P1e_earth + Psn31*P12*Pearth22*P2e_earth + Psn31*P12*Pearth23*P3e_earth + Psn31*P13*Pearth31*P1e_earth + Psn31*P13*Pearth32*P2e_earth + Psn31*P13*Pearth33*P3e_earth + Psn32*P21*Pearth11*P1e_earth + Psn32*P21*Pearth12*P2e_earth + Psn32*P21*Pearth13*P3e_earth + Psn32*P22*Pearth21*P1e_earth + Psn32*P22*Pearth22*P2e_earth + Psn32*P22*Pearth23*P3e_earth + Psn32*P23*Pearth31*P1e_earth + Psn32*P23*Pearth32*P2e_earth + Psn32*P23*Pearth33*P3e_earth + Psn33*P31*Pearth11*P1e_earth + Psn33*P31*Pearth12*P2e_earth + Psn33*P31*Pearth13*P3e_earth + Psn33*P32*Pearth21*P1e_earth + Psn33*P32*Pearth22*P2e_earth + Psn33*P32*Pearth23*P3e_earth + Psn33*P33*Pearth31*P1e_earth + Psn33*P33*Pearth32*P2e_earth + Psn33*P33*Pearth33*P3e_earth
    return Pee
